# %%
import pandas as pd

gemini3_scores = "../data_dir/checkpoints/gemini30preview/gemini30preview_scores_exclude_small_samples.json"

gpt51_scores = "../data_dir/checkpoints/gpt-5.1/gpt-5.1_scores_exclude_small_samples.json"


gemini2_scores = "../data_dir/checkpoints/gemini25pro/gemini25pro_scores_exclude_small_samples.json"

# %%
pd_gemini_3 = pd.read_json(gemini3_scores)
pd_gemini_3["PA"] = pd_gemini_3["PA"].apply(lambda x: round(x, 2) if isinstance(x, float) else x)
pd_gemini_3 = pd_gemini_3.set_index(["name", "PA", "S", "m"])

pd_gemini_3.head()
# Out:
#                             human_r0_accuracy  human_r0_precision  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500               0.59                0.57
#              0.8 140 0.400               0.75                0.64
#              1.0 230 0.139               0.93                0.70
#              All 500 0.306               0.79                0.62
# Cardiomegaly 0.6 142 0.507               0.64                0.80
#
#                             human_r0_recall  human_r0_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500             0.72               0.64
#              0.8 140 0.400             0.86               0.73
#              1.0 230 0.139             0.88               0.78
#              All 500 0.306             0.80               0.70
# Cardiomegaly 0.6 142 0.507             0.39               0.52
#
#                             human_r0_support  human_r1_accuracy  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                65               0.62
#              0.8 140 0.400                56               0.74
#              1.0 230 0.139                32               0.92
#              All 500 0.306               153               0.79
# Cardiomegaly 0.6 142 0.507                72               0.65
#
#                             human_r1_precision  human_r1_recall  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.60             0.69
#              0.8 140 0.400                0.66             0.71
#              1.0 230 0.139                0.71             0.75
#              All 500 0.306                0.64             0.71
# Cardiomegaly 0.6 142 0.507                0.62             0.83
#
#                             human_r1_f1-score  human_r1_support  ...  \
# name         PA  S   m                                           ...
# Atelectasis  0.6 130 0.500               0.64                65  ...
#              0.8 140 0.400               0.68                56  ...
#              1.0 230 0.139               0.73                32  ...
#              All 500 0.306               0.67               153  ...
# Cardiomegaly 0.6 142 0.507               0.71                72  ...
#
#                             model_f1-score  model_support  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500            0.57             65
#              0.8 140 0.400            0.63             56
#              1.0 230 0.139            0.67             32
#              All 500 0.306            0.62            153
# Cardiomegaly 0.6 142 0.507            0.67             72
#
#                             agg_human - model_mean_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                         0.086667
#              0.8 140 0.400                         0.073333
#              1.0 230 0.139                         0.073333
#              All 500 0.306                         0.070000
# Cardiomegaly 0.6 142 0.507                        -0.033333
#
#                             agg_human_mean_f1-score_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.66$\pm$0.03
#              0.8 140 0.400                0.70$\pm$0.03
#              1.0 230 0.139                0.74$\pm$0.03
#              All 500 0.306                0.69$\pm$0.02
# Cardiomegaly 0.6 142 0.507                0.64$\pm$0.10
#
#                             agg_human - model_mean_precision  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                          0.046667
#              0.8 140 0.400                          0.053333
#              1.0 230 0.139                          0.116667
#              All 500 0.306                          0.056667
# Cardiomegaly 0.6 142 0.507                          0.100000
#
#                             agg_human_mean_precision_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                 0.58$\pm$0.02
#              0.8 140 0.400                 0.62$\pm$0.05
#              1.0 230 0.139                 0.66$\pm$0.08
#              All 500 0.306                 0.61$\pm$0.04
# Cardiomegaly 0.6 142 0.507                 0.71$\pm$0.09
#
#                             agg_human - model_mean_recall  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                       0.143333
#              0.8 140 0.400                       0.133333
#              1.0 230 0.139                      -0.033333
#              All 500 0.306                       0.100000
# Cardiomegaly 0.6 142 0.507                      -0.126667
#
#                             agg_human_mean_recall_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500              0.76$\pm$0.10
#              0.8 140 0.400              0.83$\pm$0.11
#              1.0 230 0.139              0.88$\pm$0.13
#              All 500 0.306              0.81$\pm$0.11
# Cardiomegaly 0.6 142 0.507              0.62$\pm$0.22
#
#                             agg_human - model_mean_accuracy  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                         0.073333
#              0.8 140 0.400                         0.056667
#              1.0 230 0.139                         0.033333
#              All 500 0.306                         0.050000
# Cardiomegaly 0.6 142 0.507                         0.030000
#
#                             agg_human_mean_accuracy_fmt
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.60$\pm$0.02
#              0.8 140 0.400                0.73$\pm$0.03
#              1.0 230 0.139                0.91$\pm$0.02
#              All 500 0.306                0.78$\pm$0.02
# Cardiomegaly 0.6 142 0.507                0.66$\pm$0.03
#
# [5 rows x 36 columns]

# %%
pd_gemini_2 = pd.read_json(gemini2_scores)
pd_gemini_2["PA"] = pd_gemini_2["PA"].apply(lambda x: round(x, 2) if isinstance(x, float) else x)
pd_gemini_2  = pd_gemini_2.set_index(["name", "PA", "S", "m"])

pd_gemini_2.head()
# Out:
#                             human_r0_accuracy  human_r0_precision  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500               0.59                0.57
#              0.8 140 0.400               0.75                0.64
#              1.0 230 0.139               0.93                0.70
#              All 500 0.306               0.79                0.62
# Cardiomegaly 0.6 142 0.507               0.64                0.80
#
#                             human_r0_recall  human_r0_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500             0.72               0.64
#              0.8 140 0.400             0.86               0.73
#              1.0 230 0.139             0.88               0.78
#              All 500 0.306             0.80               0.70
# Cardiomegaly 0.6 142 0.507             0.39               0.52
#
#                             human_r0_support  human_r1_accuracy  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                65               0.62
#              0.8 140 0.400                56               0.74
#              1.0 230 0.139                32               0.92
#              All 500 0.306               153               0.79
# Cardiomegaly 0.6 142 0.507                72               0.65
#
#                             human_r1_precision  human_r1_recall  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.60             0.69
#              0.8 140 0.400                0.66             0.71
#              1.0 230 0.139                0.71             0.75
#              All 500 0.306                0.64             0.71
# Cardiomegaly 0.6 142 0.507                0.62             0.83
#
#                             human_r1_f1-score  human_r1_support  ...  \
# name         PA  S   m                                           ...
# Atelectasis  0.6 130 0.500               0.64                65  ...
#              0.8 140 0.400               0.68                56  ...
#              1.0 230 0.139               0.73                32  ...
#              All 500 0.306               0.67               153  ...
# Cardiomegaly 0.6 142 0.507               0.71                72  ...
#
#                             model_f1-score  model_support  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500            0.65             65
#              0.8 140 0.400            0.62             56
#              1.0 230 0.139            0.40             32
#              All 500 0.306            0.56            153
# Cardiomegaly 0.6 142 0.507            0.69             72
#
#                             agg_human - model_mean_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                         0.006667
#              0.8 140 0.400                         0.083333
#              1.0 230 0.139                         0.343333
#              All 500 0.306                         0.130000
# Cardiomegaly 0.6 142 0.507                        -0.053333
#
#                             agg_human_mean_f1-score_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.66$\pm$0.03
#              0.8 140 0.400                0.70$\pm$0.03
#              1.0 230 0.139                0.74$\pm$0.03
#              All 500 0.306                0.69$\pm$0.02
# Cardiomegaly 0.6 142 0.507                0.64$\pm$0.10
#
#                             agg_human - model_mean_precision  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                          0.066667
#              0.8 140 0.400                          0.163333
#              1.0 230 0.139                          0.406667
#              All 500 0.306                          0.206667
# Cardiomegaly 0.6 142 0.507                          0.180000
#
#                             agg_human_mean_precision_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                 0.58$\pm$0.02
#              0.8 140 0.400                 0.62$\pm$0.05
#              1.0 230 0.139                 0.66$\pm$0.08
#              All 500 0.306                 0.61$\pm$0.04
# Cardiomegaly 0.6 142 0.507                 0.71$\pm$0.09
#
#                             agg_human - model_mean_recall  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                      -0.146667
#              0.8 140 0.400                      -0.116667
#              1.0 230 0.139                      -0.093333
#              All 500 0.306                      -0.120000
# Cardiomegaly 0.6 142 0.507                      -0.336667
#
#                             agg_human_mean_recall_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500              0.76$\pm$0.10
#              0.8 140 0.400              0.83$\pm$0.11
#              1.0 230 0.139              0.88$\pm$0.13
#              All 500 0.306              0.81$\pm$0.11
# Cardiomegaly 0.6 142 0.507              0.62$\pm$0.22
#
#                             agg_human - model_mean_accuracy  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                         0.083333
#              0.8 140 0.400                         0.196667
#              1.0 230 0.139                         0.313333
#              All 500 0.306                         0.220000
# Cardiomegaly 0.6 142 0.507                         0.100000
#
#                             agg_human_mean_accuracy_fmt
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.60$\pm$0.02
#              0.8 140 0.400                0.73$\pm$0.03
#              1.0 230 0.139                0.91$\pm$0.02
#              All 500 0.306                0.78$\pm$0.02
# Cardiomegaly 0.6 142 0.507                0.66$\pm$0.03
#
# [5 rows x 36 columns]

# %%
pd_gpt_51 = pd.read_json(gpt51_scores)
pd_gpt_51["PA"] = pd_gpt_51["PA"].apply(lambda x: round(x, 2) if isinstance(x, float) else x)
pd_gpt_51  = pd_gpt_51.set_index(["name", "PA", "S", "m"])

pd_gpt_51.head()
# Out:
#                             human_r0_accuracy  human_r0_precision  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500               0.59                0.57
#              0.8 140 0.400               0.75                0.64
#              1.0 230 0.139               0.93                0.70
#              All 500 0.306               0.79                0.62
# Cardiomegaly 0.6 142 0.507               0.64                0.80
#
#                             human_r0_recall  human_r0_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500             0.72               0.64
#              0.8 140 0.400             0.86               0.73
#              1.0 230 0.139             0.88               0.78
#              All 500 0.306             0.80               0.70
# Cardiomegaly 0.6 142 0.507             0.39               0.52
#
#                             human_r0_support  human_r1_accuracy  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                65               0.62
#              0.8 140 0.400                56               0.74
#              1.0 230 0.139                32               0.92
#              All 500 0.306               153               0.79
# Cardiomegaly 0.6 142 0.507                72               0.65
#
#                             human_r1_precision  human_r1_recall  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.60             0.69
#              0.8 140 0.400                0.66             0.71
#              1.0 230 0.139                0.71             0.75
#              All 500 0.306                0.64             0.71
# Cardiomegaly 0.6 142 0.507                0.62             0.83
#
#                             human_r1_f1-score  human_r1_support  ...  \
# name         PA  S   m                                           ...
# Atelectasis  0.6 130 0.500               0.64                65  ...
#              0.8 140 0.400               0.68                56  ...
#              1.0 230 0.139               0.73                32  ...
#              All 500 0.306               0.67               153  ...
# Cardiomegaly 0.6 142 0.507               0.71                72  ...
#
#                             model_f1-score  model_support  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500            0.49             65
#              0.8 140 0.400            0.64             56
#              1.0 230 0.139            0.70             32
#              All 500 0.306            0.59            153
# Cardiomegaly 0.6 142 0.507            0.59             72
#
#                             agg_human - model_mean_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                         0.166667
#              0.8 140 0.400                         0.063333
#              1.0 230 0.139                         0.043333
#              All 500 0.306                         0.100000
# Cardiomegaly 0.6 142 0.507                         0.046667
#
#                             agg_human_mean_f1-score_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.66$\pm$0.03
#              0.8 140 0.400                0.70$\pm$0.03
#              1.0 230 0.139                0.74$\pm$0.03
#              All 500 0.306                0.69$\pm$0.02
# Cardiomegaly 0.6 142 0.507                0.64$\pm$0.10
#
#                             agg_human - model_mean_precision  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                          0.026667
#              0.8 140 0.400                         -0.076667
#              1.0 230 0.139                         -0.203333
#              All 500 0.306                         -0.053333
# Cardiomegaly 0.6 142 0.507                          0.150000
#
#                             agg_human_mean_precision_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                 0.58$\pm$0.02
#              0.8 140 0.400                 0.62$\pm$0.05
#              1.0 230 0.139                 0.66$\pm$0.08
#              All 500 0.306                 0.61$\pm$0.04
# Cardiomegaly 0.6 142 0.507                 0.71$\pm$0.09
#
#                             agg_human - model_mean_recall  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                       0.313333
#              0.8 140 0.400                       0.243333
#              1.0 230 0.139                       0.286667
#              All 500 0.306                       0.280000
# Cardiomegaly 0.6 142 0.507                       0.013333
#
#                             agg_human_mean_recall_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500              0.76$\pm$0.10
#              0.8 140 0.400              0.83$\pm$0.11
#              1.0 230 0.139              0.88$\pm$0.13
#              All 500 0.306              0.81$\pm$0.11
# Cardiomegaly 0.6 142 0.507              0.62$\pm$0.22
#
#                             agg_human - model_mean_accuracy  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                         0.063333
#              0.8 140 0.400                        -0.013333
#              1.0 230 0.139                        -0.016667
#              All 500 0.306                         0.010000
# Cardiomegaly 0.6 142 0.507                         0.100000
#
#                             agg_human_mean_accuracy_fmt
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.60$\pm$0.02
#              0.8 140 0.400                0.73$\pm$0.03
#              1.0 230 0.139                0.91$\pm$0.02
#              All 500 0.306                0.78$\pm$0.02
# Cardiomegaly 0.6 142 0.507                0.66$\pm$0.03
#
# [5 rows x 36 columns]

# %%
def df_compare_scores(df_base_model, df_target_model ):
    df_compare_scores = pd.DataFrame()
    df_compare_scores["base_f1-score"]=df_base_model["model_f1-score"]
    df_compare_scores["base_accuracy"]=df_base_model["model_accuracy"]

    df_compare_scores["target_f1-score"]=df_target_model["model_f1-score"]
    df_compare_scores["target_accuracy"]=df_target_model["model_accuracy"]

    df_compare_scores["delta_target_vs_base_model_f1-score"]= df_compare_scores["target_f1-score"] - df_compare_scores["base_f1-score"]
    df_compare_scores["delta_target_vs_base_model_accuracy"]= df_compare_scores["target_accuracy"]-df_compare_scores["base_accuracy"]

    return df_compare_scores

scores_df = pd.concat([df_compare_scores(pd_gemini_2, pd_gemini_3), df_compare_scores(pd_gemini_2, pd_gpt_51)])



# F1

scores_df.describe()
# Out:
#        base_f1-score  base_accuracy  target_f1-score  target_accuracy  \
# count      72.000000      72.000000        72.000000        72.000000
# mean        0.497778       0.548611         0.529444         0.706944
# std         0.259698       0.133113         0.237338         0.156130
# min         0.000000       0.300000         0.000000         0.260000
# 25%         0.340000       0.455000         0.430000         0.607500
# 50%         0.560000       0.560000         0.570000         0.725000
# 75%         0.730000       0.660000         0.670000         0.820000
# max         0.890000       0.860000         0.900000         0.950000
#
#        delta_target_vs_base_model_f1-score  \
# count                            72.000000
# mean                              0.031667
# std                               0.173668
# min                              -0.570000
# 25%                               0.000000
# 50%                               0.025000
# 75%                               0.102500
# max                               0.390000
#
#        delta_target_vs_base_model_accuracy
# count                            72.000000
# mean                              0.158333
# std                               0.171185
# min                              -0.260000
# 25%                               0.020000
# 50%                               0.160000
# 75%                               0.282500
# max                               0.520000

# %%
import sys
sys.path.append("../src/medical_uncertainty")
from combined_delta_analysis import create_combined_simple_box_plot_by_df

fig = create_combined_simple_box_plot_by_df(scores_df.reset_index(),"delta_target_vs_base_model_f1-score", "F1-score delta", y_label="$\\Delta$ F1:  Model - Gemini 2")
# Out:
# 4.0 0.03
# 4.0 0.03
# 4.0 0.03

# %%
fig = create_combined_simple_box_plot_by_df(scores_df.reset_index(),"delta_target_vs_base_model_accuracy", "Accuracy delta",  y_label="$\\Delta$ Acc: Model - Gemini 2")
# Out:
# 4.0 0.03
# 4.0 0.03
# 4.0 0.03
