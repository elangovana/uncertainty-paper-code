# %%
from pathlib import Path

import pandas as pd
output_dir = "../visualizations"
gemini3_scores = "../data_dir/checkpoints/gemini30preview/gemini30preview_scores_exclude_small_samples.json"

gpt51_scores = "../data_dir/checkpoints/gpt-5.1/gpt-5.1_scores_exclude_small_samples.json"

gemini31_scores="../data_dir/checkpoints/gemini31propreview/gemini31propreview_scores_exclude_small_samples.json"




gemini2_scores = "../data_dir/checkpoints/gemini25pro/gemini25pro_scores_exclude_small_samples.json"

# %%
pd_gemini_3 = pd.read_json(gemini3_scores)
pd_gemini_3["PA"] = pd_gemini_3["PA"].apply(lambda x: round(x, 2) if isinstance(x, float) else x)
pd_gemini_3 = pd_gemini_3.set_index(["name", "PA", "S", "m"])

pd_gemini_3.head()
# Out:
#                             human_r0_accuracy  human_r0_precision  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500               0.59                0.57
#              0.8 140 0.400               0.75                0.64
#              1.0 230 0.139               0.93                0.70
#              All 500 0.306               0.79                0.62
# Cardiomegaly 0.6 142 0.507               0.64                0.80
#
#                             human_r0_recall  human_r0_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500             0.72               0.64
#              0.8 140 0.400             0.86               0.73
#              1.0 230 0.139             0.88               0.78
#              All 500 0.306             0.80               0.70
# Cardiomegaly 0.6 142 0.507             0.39               0.52
#
#                             human_r0_support  human_r1_accuracy  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                65               0.62
#              0.8 140 0.400                56               0.74
#              1.0 230 0.139                32               0.92
#              All 500 0.306               153               0.79
# Cardiomegaly 0.6 142 0.507                72               0.65
#
#                             human_r1_precision  human_r1_recall  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.60             0.69
#              0.8 140 0.400                0.66             0.71
#              1.0 230 0.139                0.71             0.75
#              All 500 0.306                0.64             0.71
# Cardiomegaly 0.6 142 0.507                0.62             0.83
#
#                             human_r1_f1-score  human_r1_support  ...  \
# name         PA  S   m                                           ...
# Atelectasis  0.6 130 0.500               0.64                65  ...
#              0.8 140 0.400               0.68                56  ...
#              1.0 230 0.139               0.73                32  ...
#              All 500 0.306               0.67               153  ...
# Cardiomegaly 0.6 142 0.507               0.71                72  ...
#
#                             model_f1-score  model_support  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500            0.57             65
#              0.8 140 0.400            0.63             56
#              1.0 230 0.139            0.67             32
#              All 500 0.306            0.62            153
# Cardiomegaly 0.6 142 0.507            0.67             72
#
#                             agg_human - model_mean_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                         0.086667
#              0.8 140 0.400                         0.073333
#              1.0 230 0.139                         0.073333
#              All 500 0.306                         0.070000
# Cardiomegaly 0.6 142 0.507                        -0.033333
#
#                             agg_human_mean_f1-score_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.66$\pm$0.03
#              0.8 140 0.400                0.70$\pm$0.03
#              1.0 230 0.139                0.74$\pm$0.03
#              All 500 0.306                0.69$\pm$0.02
# Cardiomegaly 0.6 142 0.507                0.64$\pm$0.10
#
#                             agg_human - model_mean_precision  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                          0.046667
#              0.8 140 0.400                          0.053333
#              1.0 230 0.139                          0.116667
#              All 500 0.306                          0.056667
# Cardiomegaly 0.6 142 0.507                          0.100000
#
#                             agg_human_mean_precision_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                 0.58$\pm$0.02
#              0.8 140 0.400                 0.62$\pm$0.05
#              1.0 230 0.139                 0.66$\pm$0.08
#              All 500 0.306                 0.61$\pm$0.04
# Cardiomegaly 0.6 142 0.507                 0.71$\pm$0.09
#
#                             agg_human - model_mean_recall  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                       0.143333
#              0.8 140 0.400                       0.133333
#              1.0 230 0.139                      -0.033333
#              All 500 0.306                       0.100000
# Cardiomegaly 0.6 142 0.507                      -0.126667
#
#                             agg_human_mean_recall_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500              0.76$\pm$0.10
#              0.8 140 0.400              0.83$\pm$0.11
#              1.0 230 0.139              0.88$\pm$0.13
#              All 500 0.306              0.81$\pm$0.11
# Cardiomegaly 0.6 142 0.507              0.62$\pm$0.22
#
#                             agg_human - model_mean_accuracy  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                         0.073333
#              0.8 140 0.400                         0.056667
#              1.0 230 0.139                         0.033333
#              All 500 0.306                         0.050000
# Cardiomegaly 0.6 142 0.507                         0.030000
#
#                             agg_human_mean_accuracy_fmt
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.60$\pm$0.02
#              0.8 140 0.400                0.73$\pm$0.03
#              1.0 230 0.139                0.91$\pm$0.02
#              All 500 0.306                0.78$\pm$0.02
# Cardiomegaly 0.6 142 0.507                0.66$\pm$0.03
#
# [5 rows x 36 columns]

# %%
pd_gemini_2 = pd.read_json(gemini2_scores)
pd_gemini_2["PA"] = pd_gemini_2["PA"].apply(lambda x: round(x, 2) if isinstance(x, float) else x)
pd_gemini_2  = pd_gemini_2.set_index(["name", "PA", "S", "m"])

pd_gemini_2.head()
# Out:
#                             human_r0_accuracy  human_r0_precision  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500               0.59                0.57
#              0.8 140 0.400               0.75                0.64
#              1.0 230 0.139               0.93                0.70
#              All 500 0.306               0.79                0.62
# Cardiomegaly 0.6 142 0.507               0.64                0.80
#
#                             human_r0_recall  human_r0_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500             0.72               0.64
#              0.8 140 0.400             0.86               0.73
#              1.0 230 0.139             0.88               0.78
#              All 500 0.306             0.80               0.70
# Cardiomegaly 0.6 142 0.507             0.39               0.52
#
#                             human_r0_support  human_r1_accuracy  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                65               0.62
#              0.8 140 0.400                56               0.74
#              1.0 230 0.139                32               0.92
#              All 500 0.306               153               0.79
# Cardiomegaly 0.6 142 0.507                72               0.65
#
#                             human_r1_precision  human_r1_recall  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.60             0.69
#              0.8 140 0.400                0.66             0.71
#              1.0 230 0.139                0.71             0.75
#              All 500 0.306                0.64             0.71
# Cardiomegaly 0.6 142 0.507                0.62             0.83
#
#                             human_r1_f1-score  human_r1_support  ...  \
# name         PA  S   m                                           ...
# Atelectasis  0.6 130 0.500               0.64                65  ...
#              0.8 140 0.400               0.68                56  ...
#              1.0 230 0.139               0.73                32  ...
#              All 500 0.306               0.67               153  ...
# Cardiomegaly 0.6 142 0.507               0.71                72  ...
#
#                             model_f1-score  model_support  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500            0.65             65
#              0.8 140 0.400            0.62             56
#              1.0 230 0.139            0.40             32
#              All 500 0.306            0.56            153
# Cardiomegaly 0.6 142 0.507            0.69             72
#
#                             agg_human - model_mean_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                         0.006667
#              0.8 140 0.400                         0.083333
#              1.0 230 0.139                         0.343333
#              All 500 0.306                         0.130000
# Cardiomegaly 0.6 142 0.507                        -0.053333
#
#                             agg_human_mean_f1-score_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.66$\pm$0.03
#              0.8 140 0.400                0.70$\pm$0.03
#              1.0 230 0.139                0.74$\pm$0.03
#              All 500 0.306                0.69$\pm$0.02
# Cardiomegaly 0.6 142 0.507                0.64$\pm$0.10
#
#                             agg_human - model_mean_precision  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                          0.066667
#              0.8 140 0.400                          0.163333
#              1.0 230 0.139                          0.406667
#              All 500 0.306                          0.206667
# Cardiomegaly 0.6 142 0.507                          0.180000
#
#                             agg_human_mean_precision_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                 0.58$\pm$0.02
#              0.8 140 0.400                 0.62$\pm$0.05
#              1.0 230 0.139                 0.66$\pm$0.08
#              All 500 0.306                 0.61$\pm$0.04
# Cardiomegaly 0.6 142 0.507                 0.71$\pm$0.09
#
#                             agg_human - model_mean_recall  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                      -0.146667
#              0.8 140 0.400                      -0.116667
#              1.0 230 0.139                      -0.093333
#              All 500 0.306                      -0.120000
# Cardiomegaly 0.6 142 0.507                      -0.336667
#
#                             agg_human_mean_recall_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500              0.76$\pm$0.10
#              0.8 140 0.400              0.83$\pm$0.11
#              1.0 230 0.139              0.88$\pm$0.13
#              All 500 0.306              0.81$\pm$0.11
# Cardiomegaly 0.6 142 0.507              0.62$\pm$0.22
#
#                             agg_human - model_mean_accuracy  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                         0.083333
#              0.8 140 0.400                         0.196667
#              1.0 230 0.139                         0.313333
#              All 500 0.306                         0.220000
# Cardiomegaly 0.6 142 0.507                         0.100000
#
#                             agg_human_mean_accuracy_fmt
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.60$\pm$0.02
#              0.8 140 0.400                0.73$\pm$0.03
#              1.0 230 0.139                0.91$\pm$0.02
#              All 500 0.306                0.78$\pm$0.02
# Cardiomegaly 0.6 142 0.507                0.66$\pm$0.03
#
# [5 rows x 36 columns]

# %%
pd_gpt_51 = pd.read_json(gpt51_scores)
pd_gpt_51["PA"] = pd_gpt_51["PA"].apply(lambda x: round(x, 2) if isinstance(x, float) else x)
pd_gpt_51  = pd_gpt_51.set_index(["name", "PA", "S", "m"])

pd_gpt_51.head()
# Out:
#                             human_r0_accuracy  human_r0_precision  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500               0.59                0.57
#              0.8 140 0.400               0.75                0.64
#              1.0 230 0.139               0.93                0.70
#              All 500 0.306               0.79                0.62
# Cardiomegaly 0.6 142 0.507               0.64                0.80
#
#                             human_r0_recall  human_r0_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500             0.72               0.64
#              0.8 140 0.400             0.86               0.73
#              1.0 230 0.139             0.88               0.78
#              All 500 0.306             0.80               0.70
# Cardiomegaly 0.6 142 0.507             0.39               0.52
#
#                             human_r0_support  human_r1_accuracy  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                65               0.62
#              0.8 140 0.400                56               0.74
#              1.0 230 0.139                32               0.92
#              All 500 0.306               153               0.79
# Cardiomegaly 0.6 142 0.507                72               0.65
#
#                             human_r1_precision  human_r1_recall  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.60             0.69
#              0.8 140 0.400                0.66             0.71
#              1.0 230 0.139                0.71             0.75
#              All 500 0.306                0.64             0.71
# Cardiomegaly 0.6 142 0.507                0.62             0.83
#
#                             human_r1_f1-score  human_r1_support  ...  \
# name         PA  S   m                                           ...
# Atelectasis  0.6 130 0.500               0.64                65  ...
#              0.8 140 0.400               0.68                56  ...
#              1.0 230 0.139               0.73                32  ...
#              All 500 0.306               0.67               153  ...
# Cardiomegaly 0.6 142 0.507               0.71                72  ...
#
#                             model_f1-score  model_support  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500            0.49             65
#              0.8 140 0.400            0.64             56
#              1.0 230 0.139            0.70             32
#              All 500 0.306            0.59            153
# Cardiomegaly 0.6 142 0.507            0.59             72
#
#                             agg_human - model_mean_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                         0.166667
#              0.8 140 0.400                         0.063333
#              1.0 230 0.139                         0.043333
#              All 500 0.306                         0.100000
# Cardiomegaly 0.6 142 0.507                         0.046667
#
#                             agg_human_mean_f1-score_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.66$\pm$0.03
#              0.8 140 0.400                0.70$\pm$0.03
#              1.0 230 0.139                0.74$\pm$0.03
#              All 500 0.306                0.69$\pm$0.02
# Cardiomegaly 0.6 142 0.507                0.64$\pm$0.10
#
#                             agg_human - model_mean_precision  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                          0.026667
#              0.8 140 0.400                         -0.076667
#              1.0 230 0.139                         -0.203333
#              All 500 0.306                         -0.053333
# Cardiomegaly 0.6 142 0.507                          0.150000
#
#                             agg_human_mean_precision_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                 0.58$\pm$0.02
#              0.8 140 0.400                 0.62$\pm$0.05
#              1.0 230 0.139                 0.66$\pm$0.08
#              All 500 0.306                 0.61$\pm$0.04
# Cardiomegaly 0.6 142 0.507                 0.71$\pm$0.09
#
#                             agg_human - model_mean_recall  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                       0.313333
#              0.8 140 0.400                       0.243333
#              1.0 230 0.139                       0.286667
#              All 500 0.306                       0.280000
# Cardiomegaly 0.6 142 0.507                       0.013333
#
#                             agg_human_mean_recall_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500              0.76$\pm$0.10
#              0.8 140 0.400              0.83$\pm$0.11
#              1.0 230 0.139              0.88$\pm$0.13
#              All 500 0.306              0.81$\pm$0.11
# Cardiomegaly 0.6 142 0.507              0.62$\pm$0.22
#
#                             agg_human - model_mean_accuracy  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                         0.063333
#              0.8 140 0.400                        -0.013333
#              1.0 230 0.139                        -0.016667
#              All 500 0.306                         0.010000
# Cardiomegaly 0.6 142 0.507                         0.100000
#
#                             agg_human_mean_accuracy_fmt
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.60$\pm$0.02
#              0.8 140 0.400                0.73$\pm$0.03
#              1.0 230 0.139                0.91$\pm$0.02
#              All 500 0.306                0.78$\pm$0.02
# Cardiomegaly 0.6 142 0.507                0.66$\pm$0.03
#
# [5 rows x 36 columns]

# %%
pd_gemini_31 = pd.read_json(gemini31_scores)
pd_gemini_31["PA"] = pd_gemini_31["PA"].apply(lambda x: round(x, 2) if isinstance(x, float) else x)
pd_gemini_31  = pd_gemini_31.set_index(["name", "PA", "S", "m"])

pd_gemini_31.head()
# Out:
#                             human_r0_accuracy  human_r0_e_accuracy  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500               0.59                 0.60
#              0.8 140 0.400               0.75                 0.80
#              1.0 230 0.139               0.93                 0.97
#              All 500 0.306               0.79                 0.83
# Cardiomegaly 0.6 142 0.507               0.64                 0.60
#
#                             human_r0_precision  human_r0_e_precision  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.57                  0.60
#              0.8 140 0.400                0.64                  0.73
#              1.0 230 0.139                0.70                  0.84
#              All 500 0.306                0.62                  0.70
# Cardiomegaly 0.6 142 0.507                0.80                  0.61
#
#                             human_r0_recall  human_r0_e_recall  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500             0.72               0.60
#              0.8 140 0.400             0.86               0.80
#              1.0 230 0.139             0.88               0.97
#              All 500 0.306             0.80               0.75
# Cardiomegaly 0.6 142 0.507             0.39               0.60
#
#                             human_r0_f1-score  human_r0_e_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500               0.64                 0.60
#              0.8 140 0.400               0.73                 0.76
#              1.0 230 0.139               0.78                 0.90
#              All 500 0.306               0.70                 0.73
# Cardiomegaly 0.6 142 0.507               0.52                 0.60
#
#                             human_r0_support  human_r1_accuracy  ...  \
# name         PA  S   m                                           ...
# Atelectasis  0.6 130 0.500                65               0.62  ...
#              0.8 140 0.400                56               0.74  ...
#              1.0 230 0.139                32               0.92  ...
#              All 500 0.306               153               0.79  ...
# Cardiomegaly 0.6 142 0.507                72               0.65  ...
#
#                             model_e_f1-score  model_support  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500              0.60             65
#              0.8 140 0.400              0.76             56
#              1.0 230 0.139              0.90             32
#              All 500 0.306              0.73            153
# Cardiomegaly 0.6 142 0.507              0.60             72
#
#                             agg_human - model_mean_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                         0.046667
#              0.8 140 0.400                         0.073333
#              1.0 230 0.139                         0.163333
#              All 500 0.306                         0.080000
# Cardiomegaly 0.6 142 0.507                         0.206667
#
#                             agg_human_mean_f1-score_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.66$\pm$0.03
#              0.8 140 0.400                0.70$\pm$0.03
#              1.0 230 0.139                0.74$\pm$0.03
#              All 500 0.306                0.69$\pm$0.02
# Cardiomegaly 0.6 142 0.507                0.64$\pm$0.10
#
#                             E - agg_human_f1-score  E - model_f1-score  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500               -0.056667               -0.01
#              0.8 140 0.400                0.056667                0.13
#              1.0 230 0.139                0.156667                0.32
#              All 500 0.306                0.040000                0.12
# Cardiomegaly 0.6 142 0.507               -0.036667                0.17
#
#                             agg_human - model_mean_accuracy  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                         0.083333
#              0.8 140 0.400                         0.096667
#              1.0 230 0.139                         0.093333
#              All 500 0.306                         0.090000
# Cardiomegaly 0.6 142 0.507                         0.040000
#
#                             agg_human_mean_accuracy_fmt  \
# name         PA  S   m
# Atelectasis  0.6 130 0.500                0.60$\pm$0.02
#              0.8 140 0.400                0.73$\pm$0.03
#              1.0 230 0.139                0.91$\pm$0.02
#              All 500 0.306                0.78$\pm$0.02
# Cardiomegaly 0.6 142 0.507                0.66$\pm$0.03
#
#                             E - agg_human_accuracy  E - model_accuracy
# name         PA  S   m
# Atelectasis  0.6 130 0.500               -0.003333                0.08
#              0.8 140 0.400                0.073333                0.17
#              1.0 230 0.139                0.056667                0.15
#              All 500 0.306                0.050000                0.14
# Cardiomegaly 0.6 142 0.507               -0.060000               -0.02
#
# [5 rows x 52 columns]

# %%
def df_compare_scores( df_target_model, df_base_model ):
    df_compare_scores = pd.DataFrame()
    df_compare_scores["base_f1-score"]=df_base_model["model_f1-score"]
    df_compare_scores["base_accuracy"]=df_base_model["model_accuracy"]

    df_compare_scores["target_f1-score"]=df_target_model["model_f1-score"]
    df_compare_scores["target_accuracy"]=df_target_model["model_accuracy"]

    df_compare_scores["delta_target_vs_base_model_f1-score"]= df_compare_scores["target_f1-score"] - df_compare_scores["base_f1-score"]
    df_compare_scores["delta_target_vs_base_model_accuracy"]= df_compare_scores["target_accuracy"]-df_compare_scores["base_accuracy"]

    return df_compare_scores

scores_df = df_compare_scores(pd_gemini_2, pd_gemini_3)



# F1

scores_df.describe()
# Out:
#        base_f1-score  base_accuracy  target_f1-score  target_accuracy  \
# count      36.000000      36.000000        36.000000        36.000000
# mean        0.519722       0.739444         0.497778         0.548611
# std         0.230880       0.130120         0.261546         0.134061
# min         0.000000       0.510000         0.000000         0.300000
# 25%         0.357500       0.620000         0.340000         0.455000
# 50%         0.565000       0.750000         0.560000         0.560000
# 75%         0.670000       0.855000         0.730000         0.660000
# max         0.890000       0.950000         0.890000         0.860000
#
#        delta_target_vs_base_model_f1-score  \
# count                            36.000000
# mean                             -0.021944
# std                               0.211927
# min                              -0.340000
# 25%                              -0.130000
# 50%                              -0.060000
# 75%                              -0.007500
# max                               0.570000
#
#        delta_target_vs_base_model_accuracy
# count                            36.000000
# mean                             -0.190833
# std                               0.186446
# min                              -0.520000
# 25%                              -0.292500
# 50%                              -0.200000
# 75%                              -0.057500
# max                               0.260000

# %%
import sys
sys.path.append("../src/medical_uncertainty")
from combined_delta_analysis import create_combined_paired_delta_box_plot_by_df

fig = create_combined_paired_delta_box_plot_by_df(df_compare_scores(  pd_gpt_51, pd_gemini_3).reset_index(), "target_f1-score","base_f1-score", "F1-score pairwise delta", y_label="$\\Delta$ F1: GPT 5.1 - Gemini 3.0")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 5
#       2 sys.path.append("../src/medical_uncertainty")
#       3 from combined_delta_analysis import create_combined_paired_delta_box_plot_by_df
# ----> 5 fig = create_combined_paired_delta_box_plot_by_df(df_compare_scores(  pd_gpt_51, pd_gemini_3).reset_index(), "target_f1-score","base_f1-score", "F1-score pairwise delta", y_label="$\\Delta$ F1: GPT 5.1 - Gemini 3.0")
#
# File ~/PycharmProjects/uncertainty-paper-code/notebooks/../src/medical_uncertainty/combined_delta_analysis.py:146, in create_combined_paired_delta_box_plot_by_df(df, column_name_1, column_name_2, metric_label, y_label)
#     144     else:
#     145         paired_p_val = f"****"
# --> 146     boxplt.annotate(paired_p_val, xy=(i, max_delta_by_pa[pa]+0.1), horizontalalignment='center', annot_kws={"fontsize": 20})
#     148 # adding statistical annotation
#     149 ax.set_ylabel(y_label, fontsize=20, fontweight='bold')
#
# File ~/PycharmProjects/uncertainty-paper-code/.venv/lib/python3.13/site-packages/matplotlib/axes/_axes.py:721, in Axes.annotate(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#     716 @_docstring.interpd
#     717 def annotate(self, text, xy, xytext=None, xycoords='data', textcoords=None,
#     718              arrowprops=None, annotation_clip=None, **kwargs):
#     719     # Signature must match Annotation. This is verified in
#     720     # test_annotate_signature().
# --> 721     a = mtext.Annotation(text, xy, xytext=xytext, xycoords=xycoords,
#     722                          textcoords=textcoords, arrowprops=arrowprops,
#     723                          annotation_clip=annotation_clip, **kwargs)
#     724     a.set_transform(mtransforms.IdentityTransform())
#     725     if kwargs.get('clip_on', False) and a.get_clip_path() is None:
#
# File ~/PycharmProjects/uncertainty-paper-code/.venv/lib/python3.13/site-packages/matplotlib/text.py:1857, in Annotation.__init__(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    1854     self.arrow_patch = None
#    1856 # Must come last, as some kwargs may be propagated to arrow_patch.
# -> 1857 Text.__init__(self, x, y, text, **kwargs)
#
# File ~/PycharmProjects/uncertainty-paper-code/.venv/lib/python3.13/site-packages/matplotlib/text.py:155, in Text.__init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, parse_math, antialiased, **kwargs)
#     138 self._text = ''
#     139 self._reset_visual_defaults(
#     140     text=text,
#     141     color=color,
#    (...)    153     antialiased=antialiased
#     154 )
# --> 155 self.update(kwargs)
#
# File ~/PycharmProjects/uncertainty-paper-code/.venv/lib/python3.13/site-packages/matplotlib/text.py:205, in Text.update(self, kwargs)
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
# --> 205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
#     207     ret.append(self.set_bbox(bbox))
#
# File ~/PycharmProjects/uncertainty-paper-code/.venv/lib/python3.13/site-packages/matplotlib/artist.py:1223, in Artist.update(self, props)
#    1215 def update(self, props):
#    1216     """
#    1217     Update this artist's properties from the dict *props*.
#    1218
#    (...)   1221     props : dict
#    1222     """
# -> 1223     return self._update_props(
#    1224         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File ~/PycharmProjects/uncertainty-paper-code/.venv/lib/python3.13/site-packages/matplotlib/artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: 'Annotation' object has no property 'annot_kws'

# %%
fig = create_combined_paired_delta_box_plot_by_df(pd.concat([df_compare_scores( pd_gpt_51, pd_gemini_2), df_compare_scores( pd_gemini_3, pd_gemini_2)]).reset_index(), "target_f1-score","base_f1-score", "F1-score pairwise delta", y_label="$\\Delta$ F1: $\\langle$GPT 5.1, Gemini 3$\\rangle$ - Gemini 2.5")
fig.savefig(Path(output_dir) / "strong_vs_weakmodel_f1.png", dpi=400, bbox_inches='tight')

# %%
fig = create_combined_paired_delta_box_plot_by_df(pd.concat([df_compare_scores( pd_gpt_51, pd_gemini_2), df_compare_scores( pd_gemini_3, pd_gemini_2)]).reset_index(), "target_accuracy","base_accuracy", "Accuracy pairwise delta", y_label="$\\Delta$ Acc: $\\langle$GPT 5.1, Gemini 3$\\rangle$ - Gemini 2.5")
fig.savefig(Path(output_dir) / "strong_vs_weakmodel_acc.png", dpi=400, bbox_inches='tight')

# %%
fig = create_combined_paired_delta_box_plot_by_df(df_compare_scores( pd_gemini_3, pd_gemini_2).reset_index(), "target_f1-score","base_f1-score", "F1-score pairwise delta", y_label="$\\Delta$ F1: Gemini 3.0 - Gemini 2.5")
fig.savefig(Path(output_dir) / "gemni3_vs_gemini2_f1.png", dpi=400, bbox_inches='tight')

# %%
fig = create_combined_paired_delta_box_plot_by_df(df_compare_scores( pd_gemini_3, pd_gemini_2).reset_index(), "target_accuracy","base_accuracy", "Accuracy pairwise delta", y_label="$\\Delta$ Acc: Gemini 3.0 - Gemini 2.5")
fig.savefig(Path(output_dir) / "gemni3_vs_gemini2_accuracy.png", dpi=400, bbox_inches='tight')

# %%
fig = create_combined_paired_delta_box_plot_by_df(df_compare_scores( pd_gpt_51, pd_gemini_2).reset_index(), "target_f1-score","base_f1-score", "Accuracy pairwise delta", y_label="$\\Delta$ F1: GPT 5.1 - Gemini 2.5")
fig.savefig(Path(output_dir) / "gpt5_vs_gemini2_f1.png", dpi=400, bbox_inches='tight')

# %%
fig = create_combined_paired_delta_box_plot_by_df(df_compare_scores( pd_gpt_51, pd_gemini_2).reset_index(), "target_accuracy","base_accuracy", "Accuracy pairwise delta", y_label="$\\Delta$ Acc: GPT 5.1 - Gemini 2.5")
fig.savefig(Path(output_dir) / "gpt5_vs_gemini2_accuracy.png", dpi=400, bbox_inches='tight')
